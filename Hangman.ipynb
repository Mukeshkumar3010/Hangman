# %%
# Hangman game
#

# -----------------------------------
# Helper code
# You don't need to understand this helper code,
# but you will have to know how to use the functions
# (so be sure to read the docstrings!)

import random
import string

WORDLIST_FILENAME = "words.txt"

def loadWords():
    """
    Returns a list of valid words. Words are strings of lowercase letters.
    
    Depending on the size of the word list, this function may
    take a while to finish.
    """
    print("Loading word list from file...")
    # inFile: file
    inFile = open(WORDLIST_FILENAME, 'r')
    # line: string
    line = inFile.readline()
    # wordlist: list of strings
    wordlist = line.split()
    print("  ", len(wordlist), "words loaded.")
    return wordlist

def chooseWord(wordlist):
    """
    wordlist (list): list of words (strings)

    Returns a word from wordlist at random
    """
    return random.choice(wordlist)

# end of helper code
# -----------------------------------

# Load the list of words into the variable wordlist
# so that it can be accessed from anywhere in the program
wordlist = loadWords()

def isWordGuessed(secretWord, lettersGuessed):
    '''
    secretWord: string, the word the user is guessing
    lettersGuessed: list, what letters have been guessed so far
    returns: boolean, True if all the letters of secretWord are in lettersGuessed;
      False otherwise
    '''
    # FILL IN YOUR CODE HERE...
    for letter in secretWord:
        #print(letter)
        if letter in lettersGuessed:
            #print(letter)
            pass
        else:
            return False
    return True



def getGuessedWord(secretWord, lettersGuessed):
    '''
    secretWord: string, the word the user is guessing
    lettersGuessed: list, what letters have been guessed so far
    returns: string, comprised of letters and underscores that represents
      what letters in secretWord have been guessed so far.
    '''
    # FILL IN YOUR CODE HERE...
    hyphen = len(secretWord)
    hyphen = (hyphen*'- ')
    result = list(hyphen)
    for letter in lettersGuessed:
        for i in range(len(secretWord)):
            if secretWord[i] == letter:
                result[i*2]=letter
    return ''.join(result)

def getAvailableLetters(lettersGuessed):
    '''
    lettersGuessed: list, what letters have been guessed so far
    returns: string, comprised of letters that represents what letters have not
      yet been guessed.
    '''
    # FILL IN YOUR CODE HERE...
    return ''.join(sorted(set(string.ascii_lowercase).difference(lettersGuessed)))

def hangman(secretWord):
    '''
    secretWord: string, the secret word to guess.

    Starts up an interactive game of Hangman.

    * At the start of the game, let the user know how many 
      letters the secretWord contains.

    * Ask the user to supply one guess (i.e. letter) per round.

    * The user should receive feedback immediately after each guess 
      about whether their guess appears in the computers word.

    * After each round, you should also display to the user the 
      partially guessed word so far, as well as letters that the 
      user has not yet guessed.

    Follows the other limitations detailed in the problem write-up.
    '''
    # FILL IN YOUR CODE HERE...
    print("Welcome to the game Hangman!")
    
    # At the start of the game, let the user know how many letters the computer's word contains.
    print("I am thinking of a word that is " + str(len(secretWord)) +" letters long")
    print("--------")
    lettersGuessed = []
    guesses = 8
    while not isWordGuessed(secretWord, lettersGuessed) and guesses > 0:
        
        # A user is allowed 8 guesses. Make sure to remind the user of how many guesses s/he has left after each round. 
        # Assume that players will only ever submit one character at a time (A-Z).
        print("You have " + str(guesses) +" guesses left")
        
        # The user should receive feedback immediately after each guess about whether their guess appears in the computer's word
        print("Available Letters: " +getAvailableLetters(lettersGuessed))
        
        
        # If the user guesses the same letter twice, do not take away a guess - instead,
        # print a message letting them know they've already guessed that letter and ask them to try again.
        
        while True:
            
            # Ask the user to supply one guess (i.e. letter) per round
            letterGuess = input("Please guess a letter: ").lower()
            if letterGuess in lettersGuessed:
                print("Oops! You've already guessed that letter: " + getGuessedWord(secretWord, lettersGuessed))
                print("--------")
                print("You have " + str(guesses) +" guesses left")
                print("Available Letters: " +getAvailableLetters(lettersGuessed))
            else:
                break
            
        lettersGuessed +=letterGuess

        if isWordGuessed(secretWord, lettersGuessed):
            print("Good guess: " + getGuessedWord(secretWord, lettersGuessed))
            print("--------")
            print("Congratulations, you won!")
            break

        elif letterGuess in secretWord:
            print("Good guess: " + getGuessedWord(secretWord, lettersGuessed))
            print("---------")
           
        else:
            guesses-=1
            print("Oops! That letter is not in my word: " + getGuessedWord(secretWord, lettersGuessed))
            print("---------")

        if guesses == 0:
            print("Sorry, you ran out of guesses. The word was " + secretWord + ".")
            break


            
            # When you've completed your hangman function, uncomment these two lines
# and run this file to test! (hint: you might want to pick your own
# secretWord while you're testing)

secretWord = chooseWord(wordlist).lower()
hangman(secretWord)
# Out:
# Loading word list from file...
#    55909 words loaded.
# Welcome to the game Hangman!
# I am thinking of a word that is 7 letters long
# --------
# You have 8 guesses left
# Available Letters: abcdefghijklmnopqrstuvwxyz
# Please guess a letter: n
# Oops! That letter is not in my word: - - - - - - -
# ---------
# You have 7 guesses left
# Available Letters: abcdefghijklmopqrstuvwxyz
# Please guess a letter: e
# Good guess: - e - - - e -
# ---------
# You have 7 guesses left
# Available Letters: abcdfghijklmopqrstuvwxyz
# Please guess a letter: i
# Oops! That letter is not in my word: - e - - - e -
# ---------
# You have 6 guesses left
# Available Letters: abcdfghjklmopqrstuvwxyz
# Please guess a letter: o
# Oops! That letter is not in my word: - e - - - e -
# ---------
# You have 5 guesses left
# Available Letters: abcdfghjklmpqrstuvwxyz
# Please guess a letter: a
# Oops! That letter is not in my word: - e - - - e -
# ---------
# You have 4 guesses left
# Available Letters: bcdfghjklmpqrstuvwxyz
# Please guess a letter: e
# Oops! You've already guessed that letter: - e - - - e -
# --------
# You have 4 guesses left
# Available Letters: bcdfghjklmpqrstuvwxyz
# Please guess a letter: d
# Oops! That letter is not in my word: - e - - - e -
# ---------
# You have 3 guesses left
# Available Letters: bcfghjklmpqrstuvwxyz
# Please guess a letter: s
# Good guess: - e s - - e -
# ---------
# You have 3 guesses left
# Available Letters: bcfghjklmpqrtuvwxyz
# Please guess a letter: t
# Good guess: - e s t - e -
# ---------
# You have 3 guesses left
# Available Letters: bcfghjklmpqruvwxyz
# Please guess a letter: b
# Good guess: b e s t - e -
# ---------
# You have 3 guesses left
# Available Letters: cfghjklmpqruvwxyz
# Please guess a letter: l
# Oops! That letter is not in my word: b e s t - e -
# ---------
# You have 2 guesses left
# Available Letters: cfghjkmpqruvwxyz
# Please guess a letter: c
# Oops! That letter is not in my word: b e s t - e -
# ---------
# You have 1 guesses left
# Available Letters: fghjkmpqruvwxyz
# Please guess a letter: r
# Good guess: b e s t r e -
# ---------
# You have 1 guesses left
# Available Letters: fghjkmpquvwxyz
# Please guess a letter: h
# Oops! That letter is not in my word: b e s t r e -
# ---------
# Sorry, you ran out of guesses. The word was bestrew.
